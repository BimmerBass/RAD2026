# %%
import pandas as pd
df = pd.read_csv("quadratic-sums-result.csv")
df
# Out:
#    l-sample  multiply-shift-ms  multiply-mod-prime-ms   second-moment
# 0         1           499.7055              2350.7827  15637502434420
# 1         2           249.4098              2406.6589   7818751217212
# 2         4           286.8285              2864.3567   1954687804316
# 3         8           268.2439              2760.4967    122167987996
# 4        12           305.6566              2975.5313      7635502876
# 5        16           532.3830              3387.6865       477276956
# 6        20          3870.7560              9364.4915        30758236

# %%
import matplotlib.pyplot as plt

ax = df.plot(
    x='l-sample',
    y=['multiply-shift-ms', 'multiply-mod-prime-ms'],
    marker='o'
)
ax.set_xlabel('l-sample')
ax.set_ylabel('Time (ms)')
ax.set_title('multiply-shift vs multiply-mod-prime')
ax.grid(True)
